# %% [markdown]
# ### 等比数列の和

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 無限等比級数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 幾何分布

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 幾何分布には２つの意味がある

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
