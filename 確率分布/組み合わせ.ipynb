# %% [markdown]
# # 組み合わせ

# %% [markdown]
# ### 5つの椅子から２つを選ぶことを考える
#
# 全ての組み合わせ ＝ 5!\
# 選んだ２つを区別しない = 2!\
# 選ばなかった３つを区別しない = 3!

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# n個のものからr個選ぶ

# %% [markdown]
# $$
# \frac{n!}{r!(n-r)!}
# $$
