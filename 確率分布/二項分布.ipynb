# %% [markdown]
# # 二項分布

# %% [markdown]
# $X_1, X_2, X_3,..., X_n$・・・成功確率pのベルヌーイ分布

# %% [markdown]
# $X = X_1 + X_2 + X_3...+X_n$・・・で定まる分布を

# %% [markdown]
# $Bn(n, p)$と表す

# %% [markdown]
# ### 具体例
# X ... 一枚のコインをn回投げた時の表の出た枚数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
