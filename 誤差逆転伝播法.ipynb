# %% [markdown]
# # 誤差逆伝播法

# %% [markdown]
# この方法は、損失を前向き計算（forward computation）で計算したあとに、微分の連鎖律（chain rule）を利用して損失を前向き計算とは逆方向に伝播させることで、各パラメータの勾配を計算する方法です。

# %% [markdown]
# ![image.png](attachment:image.png)
